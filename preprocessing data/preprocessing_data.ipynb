# %%
import pandas as pd

# %%
DT_cohat = pd.read_csv('DTcayLTcohat15-17.csv')
DT_cohat.head(10)
# Out:
#                           2015    2016    2017
# 0              CẢ NƯỚC  9008.8  8890.6  8806.8
# 1  Ðồng bằng sông Hồng  1202.5  1184.3  1159.0
# 2               Hà Nội   221.6   217.0   209.0
# 3            Vĩnh Phúc    74.5    74.4    73.0
# 4             Bắc Ninh    75.5    73.8    71.5
# 5           Quảng Ninh    48.5    48.1    47.3
# 6            Hải Dương   126.7   124.5   122.4
# 7            Hải Phòng    77.0    75.2    73.3
# 8             Hưng Yên    86.0    82.3    78.2
# 9            Thái Bình   172.1   172.3   171.9

# %%
tinh_thanh = DT_cohat[[' ']]
nam2015 = tinh_thanh.copy()
nam2015.head(5)
# Out:
#
# 0              CẢ NƯỚC
# 1  Ðồng bằng sông Hồng
# 2               Hà Nội
# 3            Vĩnh Phúc
# 4             Bắc Ninh

# %%
nam2015['Năm'] = 2015
nam2015
# Out:
#                           Năm
# 0               CẢ NƯỚC  2015
# 1   Ðồng bằng sông Hồng  2015
# 2                Hà Nội  2015
# 3             Vĩnh Phúc  2015
# 4              Bắc Ninh  2015
# ..                  ...   ...
# 65              Cần Thơ  2015
# 66            Hậu Giang  2015
# 67            Sóc Trăng  2015
# 68             Bạc Liêu  2015
# 69               Cà Mau  2015
#
# [70 rows x 2 columns]

# %%
nam2015['Diện tích cây lương thực có hạt'] = DT_cohat['2015']

# %%
nam2015
# Out:
#                           Năm  Diện tích cây lương thực có hạt
# 0               CẢ NƯỚC  2015                           9008.8
# 1   Ðồng bằng sông Hồng  2015                           1202.5
# 2                Hà Nội  2015                            221.6
# 3             Vĩnh Phúc  2015                             74.5
# 4              Bắc Ninh  2015                             75.5
# ..                  ...   ...                              ...
# 65              Cần Thơ  2015                            239.0
# 66            Hậu Giang  2015                            210.0
# 67            Sóc Trăng  2015                            366.9
# 68             Bạc Liêu  2015                            180.7
# 69               Cà Mau  2015                            127.1
#
# [70 rows x 3 columns]

# %%
SL_cohat = pd.read_csv('SLLTcohat15-17.csv')
SL_cohat.head(10)
# Out:
#                            2015     2016     2017
# 0              CẢ NƯỚC  50379.5  48416.2  47852.2
# 1  Đồng bằng sông Hồng   7168.2   6977.9   6514.0
# 2               Hà Nội   1272.0   1206.6   1145.5
# 3            Vĩnh Phúc    395.9    361.1    385.8
# 4             Bắc Ninh    462.3    454.7    427.3
# 5           Quảng Ninh    235.2    235.4    219.3
# 6            Hải Dương    761.4    749.0    681.2
# 7            Hải Phòng    484.0    471.0    442.0
# 8             Hưng Yên    529.6    504.5    464.6
# 9            Thái Bình   1123.4   1120.1   1013.7

# %%
nam2015['Sản lượng cây lương thực có hạt'] = SL_cohat['2015']

# %%
nam2015.head(10)
# Out:
#                          Năm  Diện tích cây lương thực có hạt  \
# 0              CẢ NƯỚC  2015                           9008.8
# 1  Ðồng bằng sông Hồng  2015                           1202.5
# 2               Hà Nội  2015                            221.6
# 3            Vĩnh Phúc  2015                             74.5
# 4             Bắc Ninh  2015                             75.5
# 5           Quảng Ninh  2015                             48.5
# 6            Hải Dương  2015                            126.7
# 7            Hải Phòng  2015                             77.0
# 8             Hưng Yên  2015                             86.0
# 9            Thái Bình  2015                            172.1
#
#    Sản lượng cây lương thực có hạt
# 0                          50379.5
# 1                           7168.2
# 2                           1272.0
# 3                            395.9
# 4                            462.3
# 5                            235.2
# ...

# %%
SL_cohat_binhquan = pd.read_csv('SLLTbinhquan15-17.csv')
DT_lua = pd.read_csv('DTlua15-17.csv')
NS_lua = pd.read_csv('NSlua15-17.csv')
SL_lua = pd.read_csv('SLlua15-17.csv')
DT_dongxuan = pd.read_csv('DTluadongxuan15-17.csv')
NS_dongxuan = pd.read_csv('NSluadongxuan15-17.csv')
SL_dongxuan = pd.read_csv('SLluadongxuan15-17.csv')
DT_hethu = pd.read_csv('DTluahethuthudong15-17.csv')
NS_hethu = pd.read_csv('NSluahethuthudong15-17.csv')
SL_hethu = pd.read_csv('SLluahethuthudong15-17.csv')
DT_mua = pd.read_csv('DTluamua15-17.csv')
NS_mua = pd.read_csv('NSluamua15-17.csv')
SL_mua = pd.read_csv('SLluamua15-17.csv')
DT_ngo = pd.read_csv('DTngo15-17.csv')
NS_ngo = pd.read_csv('NSngo15-17.csv')
SL_ngo = pd.read_csv('SLngo15-17.csv')
DT_khoai = pd.read_csv('DTkhoai15-17.csv')
SL_khoai = pd.read_csv('SLkhoai15-17.csv')
DT_san = pd.read_csv('DTsan15-17.csv')
SL_san = pd.read_csv('SLsan15-17.csv')

# %%
nam2015['Sản lượng lương thực có hạt bình quân đầu người'] = SL_cohat_binhquan['2015']
nam2015['Diện tích lúa'] = DT_lua['2015']
nam2015['Năng suất lúa'] = NS_lua['2015']
nam2015['Sản lượng lúa'] = SL_lua['2015']
nam2015
# Out:
#                           Năm  Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC  2015                           9008.8
# 1   Ðồng bằng sông Hồng  2015                           1202.5
# 2                Hà Nội  2015                            221.6
# 3             Vĩnh Phúc  2015                             74.5
# 4              Bắc Ninh  2015                             75.5
# ..                  ...   ...                              ...
# 65              Cần Thơ  2015                            239.0
# 66            Hậu Giang  2015                            210.0
# 67            Sóc Trăng  2015                            366.9
# 68             Bạc Liêu  2015                            180.7
# 69               Cà Mau  2015                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# ...

# %%
nam2015['Diện tích lúa đông xuân'] = DT_dongxuan['2015']
nam2015['Năng suất lúa đông xuân'] = NS_dongxuan['2015']
nam2015['Sản lượng lúa đông xuân'] = SL_dongxuan['2015']
nam2015
# Out:
#                           Năm  Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC  2015                           9008.8
# 1   Ðồng bằng sông Hồng  2015                           1202.5
# 2                Hà Nội  2015                            221.6
# 3             Vĩnh Phúc  2015                             74.5
# 4              Bắc Ninh  2015                             75.5
# ..                  ...   ...                              ...
# 65              Cần Thơ  2015                            239.0
# 66            Hậu Giang  2015                            210.0
# 67            Sóc Trăng  2015                            366.9
# 68             Bạc Liêu  2015                            180.7
# 69               Cà Mau  2015                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# ...

# %%
import numpy as np 
nam2015['Diện tích lúa hè thu và thu đông'] = np.nan

# %%
for i in range(len(DT_hethu[' '])):
    for j in range(len(nam2015[' '])):
        if nam2015[' '][j] == DT_hethu[' '][i]:
            nam2015.loc[j, 'Diện tích lúa hè thu và thu đông'] = DT_hethu['2015'][i]

for i in range(len(DT_hethu[' '])):
    for j in range(len(nam2015[' '])):
        if nam2015[' '][j] == DT_hethu[' '][i]:
            nam2015.loc[j, 'Năng suất lúa hè thu và thu đông'] = NS_hethu['2015'][i]

for i in range(len(DT_hethu[' '])):
    for j in range(len(nam2015[' '])):
        if nam2015[' '][j] == DT_hethu[' '][i]:
            nam2015.loc[j, 'Sản lượng lúa hè thu và thu đông'] = SL_hethu['2015'][i]

# %%
nam2015[20:70]
# Out:
#                                            Năm  \
# 20                           Thái Nguyên  2015
# 21                              Lạng Sơn  2015
# 22                             Bắc Giang  2015
# 23                               Phú Thọ  2015
# 24                             Ðiện Biên  2015
# 25                              Lai Châu  2015
# 26                                Sơn La  2015
# 27                              Hoà Bình  2015
# 28  Bắc Trung Bộ và Duyên hải miền Trung  2015
# 29                             Thanh Hoá  2015
# 30                               Nghệ An  2015
# 31                               Hà Tĩnh  2015
# 32                            Quảng Bình  2015
# 33                             Quảng Trị  2015
# 34                        Thừa Thiên Huế  2015
# 35                               Ðà Nẵng  2015
# 36                             Quảng Nam  2015
# 37                            Quảng Ngãi  2015
# 38                             Bình Ðịnh  2015
# ...

# %%
nam2015['Diện tích lúa mùa'] = DT_mua['2015']
nam2015['Năng suất lúa mùa'] = NS_mua['2015']
nam2015['Sản lượng lúa mùa'] = SL_mua['2015']
nam2015
# Out:
#                           Năm  Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC  2015                           9008.8
# 1   Ðồng bằng sông Hồng  2015                           1202.5
# 2                Hà Nội  2015                            221.6
# 3             Vĩnh Phúc  2015                             74.5
# 4              Bắc Ninh  2015                             75.5
# ..                  ...   ...                              ...
# 65              Cần Thơ  2015                            239.0
# 66            Hậu Giang  2015                            210.0
# 67            Sóc Trăng  2015                            366.9
# 68             Bạc Liêu  2015                            180.7
# 69               Cà Mau  2015                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# ...

# %%
nam2015['Diện tích ngô'] = DT_ngo['2015']
nam2015['Năng suất ngô'] = NS_ngo['2015']
nam2015['Sản lượng ngô'] = SL_ngo['2015']
nam2015
# Out:
#                           Năm  Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC  2015                           9008.8
# 1   Ðồng bằng sông Hồng  2015                           1202.5
# 2                Hà Nội  2015                            221.6
# 3             Vĩnh Phúc  2015                             74.5
# 4              Bắc Ninh  2015                             75.5
# ..                  ...   ...                              ...
# 65              Cần Thơ  2015                            239.0
# 66            Hậu Giang  2015                            210.0
# 67            Sóc Trăng  2015                            366.9
# 68             Bạc Liêu  2015                            180.7
# 69               Cà Mau  2015                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# ...

# %%
nam2015['Diện tích khoai'] = DT_khoai['2015']
nam2015['Sản lượng khoai'] = SL_khoai['2015']
nam2015
# Out:
#                           Năm  Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC  2015                           9008.8
# 1   Ðồng bằng sông Hồng  2015                           1202.5
# 2                Hà Nội  2015                            221.6
# 3             Vĩnh Phúc  2015                             74.5
# 4              Bắc Ninh  2015                             75.5
# ..                  ...   ...                              ...
# 65              Cần Thơ  2015                            239.0
# 66            Hậu Giang  2015                            210.0
# 67            Sóc Trăng  2015                            366.9
# 68             Bạc Liêu  2015                            180.7
# 69               Cà Mau  2015                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# ...

# %%
nam2015
# Out:
#                           Năm  Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC  2015                           9008.8
# 1   Ðồng bằng sông Hồng  2015                           1202.5
# 2                Hà Nội  2015                            221.6
# 3             Vĩnh Phúc  2015                             74.5
# 4              Bắc Ninh  2015                             75.5
# ..                  ...   ...                              ...
# 65              Cần Thơ  2015                            239.0
# 66            Hậu Giang  2015                            210.0
# 67            Sóc Trăng  2015                            366.9
# 68             Bạc Liêu  2015                            180.7
# 69               Cà Mau  2015                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# ...

# %%
for i in range(len(DT_san[' '])):
    for j in range(len(nam2015[' '])):
        if nam2015[' '][j] == DT_san[' '][i]:
            nam2015.loc[j, 'Diện tích sắn'] = DT_san['2015'][i]

for i in range(len(SL_san[' '])):
    for j in range(len(nam2015[' '])):
        if nam2015[' '][j] == SL_san[' '][i]:
            nam2015.loc[j, 'Sản lượng sắn'] = SL_san['2015'][i]

# %%
nam2015[20:70]
# Out:
#                                            Năm  \
# 20                           Thái Nguyên  2015
# 21                              Lạng Sơn  2015
# 22                             Bắc Giang  2015
# 23                               Phú Thọ  2015
# 24                             Ðiện Biên  2015
# 25                              Lai Châu  2015
# 26                                Sơn La  2015
# 27                              Hoà Bình  2015
# 28  Bắc Trung Bộ và Duyên hải miền Trung  2015
# 29                             Thanh Hoá  2015
# 30                               Nghệ An  2015
# 31                               Hà Tĩnh  2015
# 32                            Quảng Bình  2015
# 33                             Quảng Trị  2015
# 34                        Thừa Thiên Huế  2015
# 35                               Ðà Nẵng  2015
# 36                             Quảng Nam  2015
# 37                            Quảng Ngãi  2015
# 38                             Bình Ðịnh  2015
# ...

# %%
cols = nam2015.columns.tolist()
cols
# Out:
# [' ',
#  'Năm',
#  'Diện tích cây lương thực có hạt',
#  'Sản lượng cây lương thực có hạt',
#  'Sản lượng lương thực có hạt bình quân đầu người',
#  'Diện tích lúa',
#  'Năng suất lúa',
#  'Sản lượng lúa',
#  'Diện tích lúa đông xuân',
#  'Năng suất lúa đông xuân',
#  'Sản lượng lúa đông xuân',
#  'Diện tích lúa hè thu và thu đông',
#  'Năng suất lúa hè thu và thu đông',
#  'Sản lượng lúa hè thu và thu đông',
#  'Diện tích lúa mùa',
#  'Năng suất lúa mùa',
#  'Sản lượng lúa mùa',
#  'Diện tích ngô',
#  'Năng suất ngô',
#  'Sản lượng ngô',
#  'Diện tích khoai',
#  'Sản lượng khoai',
#  'Diện tích sắn',
#  'Sản lượng sắn']

# %%
cols = [' ',
 'Diện tích cây lương thực có hạt',
 'Sản lượng cây lương thực có hạt',
 'Sản lượng lương thực có hạt bình quân đầu người',
 'Diện tích lúa',
 'Năng suất lúa',
 'Sản lượng lúa',
 'Diện tích lúa đông xuân',
 'Năng suất lúa đông xuân',
 'Sản lượng lúa đông xuân',
 'Diện tích lúa hè thu và thu đông',
 'Năng suất lúa hè thu và thu đông',
 'Sản lượng lúa hè thu và thu đông',
 'Diện tích lúa mùa',
 'Năng suất lúa mùa',
 'Sản lượng lúa mùa',
 'Diện tích ngô',
 'Năng suất ngô',
 'Sản lượng ngô',
 'Diện tích khoai',
 'Sản lượng khoai',
 'Diện tích sắn','Sản lượng sắn',
 'Năm']

# %%
nam2015 = nam2015[cols]

# %%
nam2015
# Out:
#                          Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC                           9008.8
# 1   Ðồng bằng sông Hồng                           1202.5
# 2                Hà Nội                            221.6
# 3             Vĩnh Phúc                             74.5
# 4              Bắc Ninh                             75.5
# ..                  ...                              ...
# 65              Cần Thơ                            239.0
# 66            Hậu Giang                            210.0
# 67            Sóc Trăng                            366.9
# 68             Bạc Liêu                            180.7
# 69               Cà Mau                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# 4                             462.3
# ..                              ...
# ...

# %%
nam2016 = tinh_thanh.copy()
nam2016.head()
# Out:
#
# 0              CẢ NƯỚC
# 1  Ðồng bằng sông Hồng
# 2               Hà Nội
# 3            Vĩnh Phúc
# 4             Bắc Ninh

# %%
nam2016['Diện tích cây lương thực có hạt'] = DT_cohat['2016']
nam2016['Sản lượng cây lương thực có hạt'] = SL_cohat['2016']
nam2016['Sản lượng lương thực có hạt bình quân đầu người'] = SL_cohat_binhquan['2016']
nam2016['Diện tích lúa'] = DT_lua['2016']
nam2016['Năng suất lúa'] = NS_lua['2016']
nam2016['Sản lượng lúa'] = SL_lua['2016']
nam2016['Diện tích lúa đông xuân'] = DT_dongxuan['2016']
nam2016['Năng suất lúa đông xuân'] = NS_dongxuan['2016']
nam2016['Sản lượng lúa đông xuân'] = SL_dongxuan['2016']
for i in range(len(DT_hethu[' '])):
    for j in range(len(nam2016[' '])):
        if nam2016[' '][j] == DT_hethu[' '][i]:
            nam2016.loc[j, 'Diện tích lúa hè thu và thu đông'] = DT_hethu['2016'][i]

for i in range(len(NS_hethu[' '])):
    for j in range(len(nam2016[' '])):
        if nam2016[' '][j] == DT_hethu[' '][i]:
            nam2016.loc[j, 'Năng suất lúa hè thu và thu đông'] = NS_hethu['2016'][i]

for i in range(len(SL_hethu[' '])):
    for j in range(len(nam2016[' '])):
        if nam2016[' '][j] == DT_hethu[' '][i]:
            nam2016.loc[j, 'Sản lượng lúa hè thu và thu đông'] = SL_hethu['2016'][i]
            
nam2016['Diện tích lúa mùa'] = DT_mua['2016']
nam2016['Năng suất lúa mùa'] = NS_mua['2016']
nam2016['Sản lượng lúa mùa'] = SL_mua['2016']
nam2016['Diện tích ngô'] = DT_ngo['2016']
nam2016['Năng suất ngô'] = NS_ngo['2016']
nam2016['Sản lượng ngô'] = SL_ngo['2016']
nam2016['Diện tích khoai'] = DT_khoai['2016']
nam2016['Sản lượng khoai'] = SL_khoai['2016']
for i in range(len(DT_san[' '])):
    for j in range(len(nam2016[' '])):
        if nam2016[' '][j] == DT_san[' '][i]:
            nam2016.loc[j, 'Diện tích sắn'] = DT_san['2016'][i]

for i in range(len(SL_san[' '])):
    for j in range(len(nam2016[' '])):
        if nam2016[' '][j] == SL_san[' '][i]:
            nam2016.loc[j, 'Sản lượng sắn'] = SL_san['2016'][i]
            
nam2016['Năm'] = 2016
nam2016
# Out:
#                          Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC                           8890.6
# 1   Ðồng bằng sông Hồng                           1184.3
# 2                Hà Nội                            217.0
# 3             Vĩnh Phúc                             74.4
# 4              Bắc Ninh                             73.8
# ..                  ...                              ...
# 65              Cần Thơ                            241.1
# 66            Hậu Giang                            205.5
# 67            Sóc Trăng                            360.6
# 68             Bạc Liêu                            172.5
# 69               Cà Mau                            112.8
#
#     Sản lượng cây lương thực có hạt  \
# 0                           48416.2
# 1                            6977.9
# 2                            1206.6
# 3                             361.1
# 4                             454.7
# ..                              ...
# ...

# %%
nam2017 = tinh_thanh.copy()
nam2017['Diện tích cây lương thực có hạt'] = DT_cohat['2017']
nam2017['Sản lượng cây lương thực có hạt'] = SL_cohat['2017']
nam2017['Sản lượng lương thực có hạt bình quân đầu người'] = SL_cohat_binhquan['2017']
nam2017['Diện tích lúa'] = DT_lua['2017']
nam2017['Năng suất lúa'] = NS_lua['2017']
nam2017['Sản lượng lúa'] = SL_lua['2017']
nam2017['Diện tích lúa đông xuân'] = DT_dongxuan['2017']
nam2017['Năng suất lúa đông xuân'] = NS_dongxuan['2017']
nam2017['Sản lượng lúa đông xuân'] = SL_dongxuan['2017']
for i in range(len(DT_hethu[' '])):
    for j in range(len(nam2017[' '])):
        if nam2017[' '][j] == DT_hethu[' '][i]:
            nam2017.loc[j, 'Diện tích lúa hè thu và thu đông'] = DT_hethu['2017'][i]

for i in range(len(NS_hethu[' '])):
    for j in range(len(nam2017[' '])):
        if nam2017[' '][j] == DT_hethu[' '][i]:
            nam2017.loc[j, 'Năng suất lúa hè thu và thu đông'] = NS_hethu['2017'][i]

for i in range(len(SL_hethu[' '])):
    for j in range(len(nam2017[' '])):
        if nam2017[' '][j] == DT_hethu[' '][i]:
            nam2017.loc[j, 'Sản lượng lúa hè thu và thu đông'] = SL_hethu['2017'][i]
            
nam2017['Diện tích lúa mùa'] = DT_mua['2017']
nam2017['Năng suất lúa mùa'] = NS_mua['2017']
nam2017['Sản lượng lúa mùa'] = SL_mua['2017']
nam2017['Diện tích ngô'] = DT_ngo['2017']
nam2017['Năng suất ngô'] = NS_ngo['2017']
nam2017['Sản lượng ngô'] = SL_ngo['2017']
nam2017['Diện tích khoai'] = DT_khoai['2017']
nam2017['Sản lượng khoai'] = SL_khoai['2017']
for i in range(len(DT_san[' '])):
    for j in range(len(nam2017[' '])):
        if nam2017[' '][j] == DT_san[' '][i]:
            nam2017.loc[j, 'Diện tích sắn'] = DT_san['2017'][i]

for i in range(len(SL_san[' '])):
    for j in range(len(nam2017[' '])):
        if nam2017[' '][j] == SL_san[' '][i]:
            nam2017.loc[j, 'Sản lượng sắn'] = SL_san['2017'][i]
            
nam2017['Năm'] = 2017
nam2017
# Out:
#                          Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC                           8806.8
# 1   Ðồng bằng sông Hồng                           1159.0
# 2                Hà Nội                            209.0
# 3             Vĩnh Phúc                             73.0
# 4              Bắc Ninh                             71.5
# ..                  ...                              ...
# 65              Cần Thơ                            241.2
# 66            Hậu Giang                            209.8
# 67            Sóc Trăng                            352.4
# 68             Bạc Liêu                            180.8
# 69               Cà Mau                            113.6
#
#     Sản lượng cây lương thực có hạt  \
# 0                           47852.2
# 1                            6514.0
# 2                            1145.5
# 3                             385.8
# 4                             427.3
# ..                              ...
# ...

# %%
nam2015.to_csv('2015.csv', index=False, encoding='utf-8')
nam2016.to_csv('2016.csv', index=False, encoding='utf-8')
nam2017.to_csv('2017.csv', index=False, encoding='utf-8')

# %%
df1 = pd.read_csv('2015.csv')
df1.head(10)
# Out:
#                         Diện tích cây lương thực có hạt  \
# 0              CẢ NƯỚC                           9008.8
# 1  Ðồng bằng sông Hồng                           1202.5
# 2               Hà Nội                            221.6
# 3            Vĩnh Phúc                             74.5
# 4             Bắc Ninh                             75.5
# 5           Quảng Ninh                             48.5
# 6            Hải Dương                            126.7
# 7            Hải Phòng                             77.0
# 8             Hưng Yên                             86.0
# 9            Thái Bình                            172.1
#
#    Sản lượng cây lương thực có hạt  \
# 0                          50379.5
# 1                           7168.2
# 2                           1272.0
# 3                            395.9
# 4                            462.3
# 5                            235.2
# 6                            761.4
# 7                            484.0
# ...

# %%
frames = [nam2015, nam2016, nam2017]

df15_17 = pd.concat(frames, ignore_index=True)

# %%
df15_17[60:90]
# Out:
#                                    Diện tích cây lương thực có hạt  \
# 60                       Trà Vinh                            241.4
# 61                      Vĩnh Long                            181.7
# 62                      Ðồng Tháp                            550.5
# 63                       An Giang                            652.8
# 64                     Kiên Giang                            769.7
# 65                        Cần Thơ                            239.0
# 66                      Hậu Giang                            210.0
# 67                      Sóc Trăng                            366.9
# 68                       Bạc Liêu                            180.7
# 69                         Cà Mau                            127.1
# 70                        CẢ NƯỚC                           8890.6
# 71            Ðồng bằng sông Hồng                           1184.3
# 72                         Hà Nội                            217.0
# ...

# %%
nam_2015 = nam2015.copy()

# %%
nam2015.rename(columns = {' ':'Tỉnh thành'}, inplace = True)
nam2016.rename(columns = {' ':'Tỉnh thành'}, inplace = True)
nam2017.rename(columns = {' ':'Tỉnh thành'}, inplace = True)

# %%
xls12_14 = pd.ExcelFile('2012-2014.xlsx')
nam2012 = pd.read_excel(xls12_14, '2012')
nam2013 = pd.read_excel(xls12_14, '2013')
nam2014 = pd.read_excel(xls12_14, '2014')

# %%
nam2012['Năm'] = 2012
nam2013['Năm'] = 2013
nam2014['Năm'] = 2014

# %%
nam2012
# Out:
#              Tỉnh thành  Diện tích cây lương thực có hạt  \
# 0               Cả nước                           8918.9
# 1   Đồng bằng sông Hồng                           1225.2
# 2                Hà Nội                            225.9
# 3             Vĩnh Phúc                             73.1
# 4              Bắc Ninh                             76.9
# ..                  ...                              ...
# 65              Cần Thơ                            229.3
# 66            Hậu Giang                            216.3
# 67            Sóc Trăng                            369.7
# 68             Bạc Liêu                            178.8
# 69               Cà Mau                            129.7
#
#     Sản lượng cây lương thực có hạt  \
# 0                           48712.6
# 1                            7285.2
# 2                            1301.9
# 3                             355.6
# 4                             471.9
# ..                              ...
# ...

# %%
nam2015
# Out:
#              Tỉnh thành  Diện tích cây lương thực có hạt  \
# 0               CẢ NƯỚC                           9008.8
# 1   Ðồng bằng sông Hồng                           1202.5
# 2                Hà Nội                            221.6
# 3             Vĩnh Phúc                             74.5
# 4              Bắc Ninh                             75.5
# ..                  ...                              ...
# 65              Cần Thơ                            239.0
# 66            Hậu Giang                            210.0
# 67            Sóc Trăng                            366.9
# 68             Bạc Liêu                            180.7
# 69               Cà Mau                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# 4                             462.3
# ..                              ...
# ...

# %%
xls08_11 = pd.ExcelFile('2008-2011.xlsx')
nam2008 = pd.read_excel(xls08_11, '2008')
nam2009 = pd.read_excel(xls08_11, '2009')
nam2010 = pd.read_excel(xls08_11, '2010')
nam2011 = pd.read_excel(xls08_11, '2011')

nam2008['Năm'] = 2008
nam2009['Năm'] = 2009
nam2010['Năm'] = 2010
nam2011['Năm'] = 2011

# %%
nam2013.columns
# Out:
# Index(['Tỉnh thành', 'Diện tích cây lương thực có hạt',
#        'Sản lượng cây lương thực có hạt',
#        'Sản lượng lương thực có hạt bình quân đầu người', 'Diện tích lúa',
#        'Năng suất lúa', 'Sản lượng lúa', 'Diện tích lúa đông xuân',
#        'Năng suất lúa đông xuân', 'Sản lượng lúa đông xuân',
#        'Diện tích lúa hè thu và thu đông', 'Năng suất lúa hè thu và thu đông',
#        'Sản lượng lúa hè thu và thu đông', 'Diện tích lúa mùa',
#        'Năng suất lúa mùa', 'Sản lượng lúa mùa', 'Diện tích ngô',
#        'Năng suất ngô', 'Sản lượng ngô', 'Diện tích khoai', 'Sản lượng khoai',
#        'Diện tích sắn', 'Sản lượng sắn', 'Năm'],
#       dtype='object')

# %%
'Đà Nẵng' == 'Ðà Nẵng'
# Out:
# False

# %%
df['Tỉnh thành'].unique()
# Out:
# array(['Cả nước', 'Đồng bằng sông Hồng', 'Hà Nội', 'Vĩnh Phúc',
#        'Bắc Ninh', 'Quảng Ninh', 'Hải Dương', 'Hải Phòng', 'Hưng Yên',
#        'Thái Bình', 'Hà Nam', 'Nam Định', 'Ninh Bình',
#        'Trung du và miền núi phía Bắc', 'Hà Giang', 'Cao Bằng', 'Bắc Kạn',
#        'Tuyên Quang', 'Lào Cai', 'Yên Bái', 'Thái Nguyên', 'Lạng Sơn',
#        'Bắc Giang', 'Phú Thọ', 'Điện Biên', 'Lai Châu', 'Sơn La',
#        'Hoà Bình', 'Bắc Trung Bộ và Duyên hải miền Trung', 'Thanh Hoá',
#        'Nghệ An', 'Hà Tĩnh', 'Quảng Bình', 'Quảng Trị', 'Thừa Thiên Huế',
#        'Đà Nẵng', 'Quảng Nam', 'Quảng Ngãi', 'Bình Định', 'Phú Yên',
#        'Khánh Hoà', 'Ninh Thuận', 'Bình Thuận', 'Tây Nguyên', 'Kon Tum',
#        'Gia Lai', 'Đắk Lắk', 'Đắk Nông', 'Lâm Đồng', 'Đông Nam Bộ',
#        'Bình Phước', 'Tây Ninh', 'Bình Dương', 'Đồng Nai',
#        'Bà Rịa - Vũng Tàu', 'TP.Hồ Chí Minh', 'Đồng bằng sông Cửu Long',
#        'Long An', 'Tiền Giang', 'Bến Tre', 'Trà Vinh', 'Vĩnh Long',
# ...

# %%
nam2015['Tỉnh thành']
# Out:
# 0                 CẢ NƯỚC
# 1     Ðồng bằng sông Hồng
# 2                  Hà Nội
# 3               Vĩnh Phúc
# 4                Bắc Ninh
#              ...
# 65                Cần Thơ
# 66              Hậu Giang
# 67              Sóc Trăng
# 68               Bạc Liêu
# 69                 Cà Mau
# Name: Tỉnh thành, Length: 70, dtype: object

# %%
'Ðiện Biên' =='Điện Biên'
# Out:
# False

# %%
'Điện Biên'=='Điện Biên'
# Out:
# True

# %%
for tinh in nam2015['Tỉnh thành']:
    if tinh == 'CẢ NƯỚC':
        tinh = 'Cả nước'

# %%
nam2015['Tỉnh thành'].unique()
# Out:
# array(['CẢ NƯỚC', 'Ðồng bằng sông Hồng', 'Hà Nội', 'Vĩnh Phúc',
#        'Bắc Ninh', 'Quảng Ninh', 'Hải Dương', 'Hải Phòng', 'Hưng Yên',
#        'Thái Bình', 'Hà Nam', 'Nam Ðịnh', 'Ninh Bình',
#        'Trung du và miền núi phía Bắc', 'Hà Giang', 'Cao Bằng', 'Bắc Kạn',
#        'Tuyên Quang', 'Lào Cai', 'Yên Bái', 'Thái Nguyên', 'Lạng Sơn',
#        'Bắc Giang', 'Phú Thọ', 'Ðiện Biên', 'Lai Châu', 'Sơn La',
#        'Hoà Bình', 'Bắc Trung Bộ và Duyên hải miền Trung', 'Thanh Hoá',
#        'Nghệ An', 'Hà Tĩnh', 'Quảng Bình', 'Quảng Trị', 'Thừa Thiên Huế',
#        'Ðà Nẵng', 'Quảng Nam', 'Quảng Ngãi', 'Bình Ðịnh', 'Phú Yên',
#        'Khánh Hoà', 'Ninh Thuận', 'Bình Thuận', 'Tây Nguyên', 'Kon Tum',
#        'Gia Lai', 'Ðắk Lắk', 'Ðắk Nông', 'Lâm Ðồng', 'Ðông Nam Bộ',
#        'Bình Phước', 'Tây Ninh', 'Bình Dương', 'Ðồng Nai',
#        'Bà Rịa - Vũng Tàu', 'TP.Hồ Chí Minh', 'Ðồng bằng sông Cửu Long',
#        'Long An', 'Tiền Giang', 'Bến Tre', 'Trà Vinh', 'Vĩnh Long',
# ...

# %%
nam2008['Tỉnh thành'][38]==nam2015['Tỉnh thành'][38]
# Out:
# True

# %%
for i in range(len(nam2015['Tỉnh thành'])):
    if nam2015['Tỉnh thành'][i] != nam2008['Tỉnh thành'][i]:
        nam2015.loc[i, 'Tỉnh thành'] = nam2008['Tỉnh thành'][i]

# %%
nam2015
# Out:
#              Tỉnh thành  Diện tích cây lương thực có hạt  \
# 0               Cả nước                           9008.8
# 1   Đồng bằng sông Hồng                           1202.5
# 2                Hà Nội                            221.6
# 3             Vĩnh Phúc                             74.5
# 4              Bắc Ninh                             75.5
# ..                  ...                              ...
# 65              Cần Thơ                            239.0
# 66            Hậu Giang                            210.0
# 67            Sóc Trăng                            366.9
# 68             Bạc Liêu                            180.7
# 69               Cà Mau                            127.1
#
#     Sản lượng cây lương thực có hạt  \
# 0                           50379.5
# 1                            7168.2
# 2                            1272.0
# 3                             395.9
# 4                             462.3
# ..                              ...
# ...

# %%
for i in range(len(nam2016['Tỉnh thành'])):
    if nam2016['Tỉnh thành'][i] != nam2008['Tỉnh thành'][i]:
        nam2016.loc[i, 'Tỉnh thành'] = nam2008['Tỉnh thành'][i]

for i in range(len(nam2017['Tỉnh thành'])):
    if nam2017['Tỉnh thành'][i] != nam2008['Tỉnh thành'][i]:
        nam2017.loc[i, 'Tỉnh thành'] = nam2008['Tỉnh thành'][i]

# %%
df['Tỉnh thành'].unique()
# Out:
# array(['Cả nước', 'Đồng bằng sông Hồng', 'Hà Nội', 'Vĩnh Phúc',
#        'Bắc Ninh', 'Quảng Ninh', 'Hải Dương', 'Hải Phòng', 'Hưng Yên',
#        'Thái Bình', 'Hà Nam', 'Nam Định', 'Ninh Bình',
#        'Trung du và miền núi phía Bắc', 'Hà Giang', 'Cao Bằng', 'Bắc Kạn',
#        'Tuyên Quang', 'Lào Cai', 'Yên Bái', 'Thái Nguyên', 'Lạng Sơn',
#        'Bắc Giang', 'Phú Thọ', 'Điện Biên', 'Lai Châu', 'Sơn La',
#        'Hoà Bình', 'Bắc Trung Bộ và Duyên hải miền Trung', 'Thanh Hoá',
#        'Nghệ An', 'Hà Tĩnh', 'Quảng Bình', 'Quảng Trị', 'Thừa Thiên Huế',
#        'Đà Nẵng', 'Quảng Nam', 'Quảng Ngãi', 'Bình Định', 'Phú Yên',
#        'Khánh Hoà', 'Ninh Thuận', 'Bình Thuận', 'Tây Nguyên', 'Kon Tum',
#        'Gia Lai', 'Đắk Lắk', 'Đắk Nông', 'Lâm Đồng', 'Đông Nam Bộ',
#        'Bình Phước', 'Tây Ninh', 'Bình Dương', 'Đồng Nai',
#        'Bà Rịa - Vũng Tàu', 'TP.Hồ Chí Minh', 'Đồng bằng sông Cửu Long',
#        'Long An', 'Tiền Giang', 'Bến Tre', 'Trà Vinh', 'Vĩnh Long',
# ...

# %%
df.to_csv('preprocessed_data.csv', index=False)

# %%
df
# Out:
#               Tỉnh thành  Diện tích cây lương thực có hạt  \
# 0                Cả nước                           8542.2
# 1    Đồng bằng sông Hồng                           1251.7
# 2                 Hà Nội                            232.6
# 3              Vĩnh Phúc                             76.4
# 4               Bắc Ninh                             78.7
# ..                   ...                              ...
# 695              Cần Thơ                            241.2
# 696            Hậu Giang                            209.8
# 697            Sóc Trăng                            352.4
# 698             Bạc Liêu                            180.8
# 699               Cà Mau                            113.6
#
#      Sản lượng cây lương thực có hạt  \
# 0                            43305.4
# 1                             7219.5
# 2                             1288.8
# 3                               37.5
# 4                              450.1
# ...
